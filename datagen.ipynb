# %%
from NVE_lj import mdlj
mdlj(nstep=3000, rho=0.84, m=6, kt=0.9, dt=0.005, freq=1, mode=0)
# Out:
# # initial (kinetic) temperature kt =  0.9000
# # integration time step dt =  0.0050
# # number of time steps for this run ns =3000
# # reference side of the cubic MD-box L(0) =  10.0943
# # number of particles  N =864
# # density rho =  0.8400
# # number of lattice cells m^3 = 216
# # lattice parameter a =1.682391
# # number of particles  864
# # sides of md-box L = [ 10.09 10.09 10.09 ]
#   0     -0.002      0.011     -0.027
#   1      0.867      0.845      0.025
#   2      0.840      0.008      0.856
#   3      0.027      0.810       0.862
#   4      0.005     -0.027      1.665
#   5      0.861      0.832      1.666
#   6      0.771      0.009      2.499
#   7      0.009      0.805       2.572
#   8     -0.018      0.004      3.371
#   9      0.844      0.863      3.355
#   10      0.817      0.002      4.193
#   11     -0.024      0.842       4.177
#   12     -0.039      0.005      5.041
#   13      0.831      0.878      5.049
#   14      0.858      0.064      5.907
# ...

# %%
mdlj(nstep=3000, rho=0.84, m=6, kt=0.9, dt=0.005, freq=1, mode=2)
# Out:
# # initial (kinetic) temperature kt =  0.9000
# # integration time step dt =  0.0050
# # number of time steps for this run ns =3000
# # reference side of the cubic MD-box L(0) =  10.0943
# # number of particles  N =864
# # density rho =  0.8400
#  initial momenta sampled from maxwellian at temperature   0.9000
# # starting with box side at initial time L(t=0) =  10.0943
#    'time'    'enep'    'enek'  'vir_p'   'enet'        'vcmx'   'vcmy'   'vcmz'
#     0.000    -6.015     1.394     -8319 -3992.8783702 8.53e-14 1.14e-13 -5.68e-14
#     0.005     -6.02     1.398     -8383 -3992.8957217 9.95e-14 1.71e-13 1.42e-14
#     0.010    -6.018     1.397     -8361 -3992.8985164 1.56e-13 2.27e-13 0.00e+00
#     0.015    -6.011      1.39     -8252 -3992.8855207 7.82e-14 1.99e-13 -1.42e-14
#     0.020    -5.998     1.377     -8063 -3992.8550992 1.56e-13 5.68e-14 -7.11e-15
#     0.025     -5.98     1.359     -7802 -3992.8083843 2.13e-14 1.71e-13 8.53e-14
# ...
